# %%
# importing pandas
import pandas as pd

# %%
# read the csv data set 
car_df=pd.read_csv('Cars_Data_1.csv')
car_df.head()
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         2.4        4.0       200.0      22.0         29.0  3230.0
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
# 4         3.5        6.0       225.0      18.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %%
car_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 432 entries, 0 to 431
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Make         428 non-null    object
#  1   Model        428 non-null    object
#  2   Type         428 non-null    object
#  3   Origin       428 non-null    object
#  4   DriveTrain   428 non-null    object
#  5   MSRP         428 non-null    object
#  6   Invoice      428 non-null    object
#  7   EngineSize   428 non-null    float64
#  8   Cylinders    426 non-null    float64
#  9   Horsepower   428 non-null    float64
#  10  MPG_City     428 non-null    float64
#  11  MPG_Highway  428 non-null    float64
#  12  Weight       428 non-null    float64
#  13  Wheelbase    428 non-null    float64
#  14  Length       428 non-null    float64
# dtypes: float64(8), object(7)
# memory usage: 50.8+ KB

# %%
car_df.describe()
# Out:
#        EngineSize   Cylinders  Horsepower    MPG_City  MPG_Highway  \
# count  428.000000  426.000000  428.000000  428.000000   428.000000
# mean     3.196729    5.807512  215.885514   20.060748    26.843458
# std      1.108595    1.558443   71.836032    5.238218     5.741201
# min      1.300000    3.000000   73.000000   10.000000    12.000000
# 25%      2.375000    4.000000  165.000000   17.000000    24.000000
# 50%      3.000000    6.000000  210.000000   19.000000    26.000000
# 75%      3.900000    6.000000  255.000000   21.250000    29.000000
# max      8.300000   12.000000  500.000000   60.000000    66.000000
#
#             Weight   Wheelbase      Length
# count   428.000000  428.000000  428.000000
# mean   3577.953271  108.154206  186.362150
# std     758.983215    8.311813   14.357991
# min    1850.000000   89.000000  143.000000
# 25%    3104.000000  103.000000  178.000000
# 50%    3474.500000  107.000000  187.000000
# 75%    3977.750000  112.000000  194.000000
# ...

# %%
# no. of rows and column
car_df.shape
# Out:
# (432, 15)

# %%
car_df[['MSRP']].head(2)
# Out:
#        MSRP
# 0  $36,945
# 1  $23,820

# %%
car_df['MSRP'].fillna(car_df['MSRP'].mean() , inplace=True)

# %%
car_df['MSRP'] = car_df['MSRP'].str.replace(',', '').str.replace('$', '').astype(float)
# Out:
# C:\Users\ushak\AppData\Local\Temp\ipykernel_9012\3285822473.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   car_df['MSRP'] = car_df['MSRP'].str.replace(',', '').str.replace('$', '').astype(float)

# %% [markdown]
# # Instruction for Data Cleaning
# ## Q 1. Find all the NULL values in the column, and fill it with the mean of that column

# %%
# show all the NULL values
car_df.isnull().sum()
# Out:
# Make           4
# Model          4
# Type           4
# Origin         4
# DriveTrain     4
# MSRP           0
# Invoice        4
# EngineSize     0
# Cylinders      0
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         0
# Wheelbase      0
# Length         0
# dtype: int64

# %%
car_df.head(2)
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0

# %%
car_df['Make'].isnull().sum()
# Out:
# 4

# %%
make_missing=pd.isnull(car_df['Make']).sum()
print(make_missing)
# Out:
# 4

# %%
## filling the null values LENGTH
car_df['Length'].fillna(car_df['Length'].mean() , inplace=True)

# %%
car_df['Wheelbase'].fillna(car_df['Wheelbase'].mean(),inplace=True)

# %%
car_df['Weight'].fillna(car_df['Weight'].mean(), inplace=True)

# %%
car_df['MPG_Highway'].fillna(car_df['MPG_Highway'].mean(), inplace=True)

# %%
car_df['MPG_City'].fillna(car_df['MPG_City'].mean(), inplace=True)

# %%
car_df['Horsepower'].fillna(car_df['Horsepower'].mean(), inplace=True)

# %%
car_df['Cylinders'].fillna(car_df['Cylinders'].mean(), inplace=True)

# %%
car_df['EngineSize'].fillna(car_df['EngineSize'].mean(), inplace=True)

# %%
car_df[['MPG_Highway','MPG_City','Horsepower','Cylinders']].fillna(car_df[['MPG_Highway','MPG_City','Horsepower','Cylinders']].mean() , inplace=True)
# Out:
# C:\Users\ushak\AppData\Local\Temp\ipykernel_9012\2527197325.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car_df[['MPG_Highway','MPG_City','Horsepower','Cylinders']].fillna(car_df[['MPG_Highway','MPG_City','Horsepower','Cylinders']].mean() , inplace=True)

# %%
car_df[['MPG_Highway','MPG_City','Horsepower','Cylinders']].mean()
# Out:
# MPG_Highway     26.843458
# MPG_City        20.060748
# Horsepower     215.885514
# Cylinders        5.807512
# dtype: float64

# %% [markdown]
# # Question based on value column
# ## Q 2. find different types of make and their count

# %%
car_df.head(2)
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0

# %%
car_df['Make'].value_counts()
# Out:
# Toyota           28
# Chevrolet        27
# Mercedes-Benz    26
# Ford             23
# BMW              20
# Audi             19
# Honda            17
# Nissan           17
# Volkswagen       15
# Chrysler         15
# Dodge            13
# Mitsubishi       13
# Volvo            12
# Jaguar           12
# Hyundai          12
# Subaru           11
# Pontiac          11
# Mazda            11
# Lexus            11
# Kia              11
# Buick             9
# Mercury           9
# Lincoln           9
# Saturn            8
# Cadillac          8
# Suzuki            8
# Infiniti          8
# GMC               8
# Acura             7
# Porsche           7
# Saab              7
# Land Rover        3
# Oldsmobile        3
# Jeep              3
# Scion             2
# Isuzu             2
# MINI              2
# Hummer            1
# Name: Make, dtype: int64

# %%
car_df['Type'].value_counts()
# Out:
# Sedan     262
# SUV        60
# Sports     49
# Wagon      30
# Truck      24
# Hybrid      3
# Name: Type, dtype: int64

# %%
car_df['Origin'].value_counts()
# Out:
# Asia      158
# USA       147
# Europe    123
# Name: Origin, dtype: int64

# %%
car_df.head(2)
# Out:
#     Make           Model   Type Origin DriveTrain     MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  36945.0  $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  23820.0  $21,761
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0

# %% [markdown]
# ## removing dollar sign from 'invoice' and put mean value into nan.

# %%
car_df['Invoice']=car_df['Invoice'].str.replace(',','').str.replace('$','').astype(float)
# Out:
# C:\Users\ushak\AppData\Local\Temp\ipykernel_9012\3315899237.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   car_df['Invoice']=car_df['Invoice'].str.replace(',','').str.replace('$','').astype(float)

# %%
car_df.head(2)
# Out:
#     Make           Model   Type Origin DriveTrain     MSRP  Invoice  \
# 0  Acura             MDX    SUV   Asia        All  36945.0  33337.0
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  23820.0  21761.0
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0

# %%
car_df['Invoice'].isnull().sum()
# Out:
# 4

# %%
car_df['Invoice'].fillna(car_df['Invoice'].mean(),inplace=True)

# %%
car_df['Invoice'].isnull().sum()
# Out:
# 0

# %%
car_df['Invoice'].mean()
# Out:
# 30014.70093457944

# %% [markdown]
# # Filtiring
# ## Q 3. show all the records where origin is asia or europe

# %%
car_df.head(2)
# Out:
#     Make           Model   Type Origin DriveTrain     MSRP  Invoice  \
# 0  Acura             MDX    SUV   Asia        All  36945.0  33337.0
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  23820.0  21761.0
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0

# %% [raw]
# car_df[car_df['Origin'].isin(['Asia','Europe'])]

# %% [markdown]
# # Instruction (remove unwanted records)
# # Q 4. Remove all the records where weight is above 4000

# %%
car_df.head(2)
# Out:
#     Make           Model   Type Origin DriveTrain     MSRP  Invoice  \
# 0  Acura             MDX    SUV   Asia        All  36945.0  33337.0
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  23820.0  21761.0
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0

# %%
car_df[~(car_df['Weight']>4000)]
# Out:
#       Make                    Model   Type  Origin DriveTrain     MSRP  \
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  23820.0
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  26990.0
# 3    Acura                   TL 4dr  Sedan    Asia      Front  33195.0
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  43755.0
# 5    Acura  3.5 RL w/Navigation 4dr  Sedan    Asia      Front  46100.0
# ..     ...                      ...    ...     ...        ...      ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  40565.0
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  42565.0
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  45210.0
# 430  Volvo                      V40  Wagon  Europe      Front  26135.0
# 431  Volvo                     XC70  Wagon  Europe        All  35145.0
#
#      Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %% [markdown]
# # Instruction (applying fucntion on a column)
# ## Q 5. Increase all the values of 'MPG_City' column by 3.

# %%
car_df.head(2)
# Out:
#     Make           Model   Type Origin DriveTrain     MSRP  Invoice  \
# 0  Acura             MDX    SUV   Asia        All  36945.0  33337.0
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  23820.0  21761.0
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0

# %%
car_df['MPG_City']=car_df['MPG_City']+3

# %%
car_df.head(2)
# Out:
#     Make           Model   Type Origin DriveTrain     MSRP  Invoice  \
# 0  Acura             MDX    SUV   Asia        All  36945.0  33337.0
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  23820.0  21761.0
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      20.0         23.0  4451.0
# 1         2.0        4.0       200.0      27.0         31.0  2778.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0

# %%
## Alternate Method
car_df['MPG_City']=car_df['MPG_City'].apply(lambda x:x+3)

# %%
car_df.head(2)
# Out:
#     Make           Model   Type Origin DriveTrain     MSRP  Invoice  \
# 0  Acura             MDX    SUV   Asia        All  36945.0  33337.0
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  23820.0  21761.0
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      23.0         23.0  4451.0
# 1         2.0        4.0       200.0      30.0         31.0  2778.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
