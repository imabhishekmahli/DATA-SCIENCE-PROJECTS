# %% [markdown]
# ## WEATHER DATA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#reading the data set 
df=pd.read_csv('Weather_Data.csv')

# %%
## FIRST 5 DATA
df.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
# shape of the dataset 
df.shape
# Out:
# (8784, 8)

# %%
# total index in the dataset
df.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %%
#all columns
df.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
# data types
df.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
# shows all the unique values in the "column"
df['Rel Hum_%'].unique()
# Out:
# array([ 86,  87,  89,  88,  85,  91,  82,  81,  84,  79,  77,  72,  71,
#         69,  70,  68,  67,  66,  56,  57,  59,  55,  54,  58,  65,  53,
#         60,  61,  63,  52,  50,  49,  62,  51,  75,  73,  80,  83,  76,
#         64,  74,  78,  47,  90,  48,  45,  46,  92,  93,  42,  43,  40,
#         39,  44,  94,  37,  41,  38,  96,  98,  99,  97,  95, 100,  29,
#         28,  27,  19,  20,  18,  25,  26,  30,  24,  34,  33,  31,  32,
#         35,  36,  21,  22,  23], dtype=int64)

# %%
df['Rel Hum_%'].nunique()
# Out:
# 83

# %%
df.count()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
## All the unique values with their count
df['Weather'].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
## Provides basic informatin about the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %% [markdown]
# ## Q 1. Find all the unique "wind speed value" in the data?

# %%
df['Wind Speed_km/h'].unique
# Out:
# <bound method Series.unique of 0        4
# 1        4
# 2        7
# 3        6
# 4        7
#         ..
# 8779    30
# 8780    24
# 8781    28
# 8782    28
# 8783    30
# Name: Wind Speed_km/h, Length: 8784, dtype: int64>

# %% [markdown]
# ## Q 2.Find the number of time when the weather is exactly 'clear' ?

# %%
df['Weather'].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
## filtering
df[df.Weather=='Clear']
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
## groupby
df.groupby('Weather').get_group('Clear')
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# ...

# %% [markdown]
# ## Q. 3 Find the number of times when the wind speed was exactly '4 km/hr' ?

# %%
df.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
df[df['Wind Speed_km/h']==4]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 96       1/5/2012 0:00    -8.8             -11.7         79                4
# 101      1/5/2012 5:00    -7.0              -9.5         82                4
# 146      1/7/2012 2:00    -8.1             -11.1         79                4
# ...                ...     ...               ...        ...              ...
# 8768   12/31/2012 8:00    -8.6             -10.3         87                4
# 8769   12/31/2012 9:00    -8.1              -9.6         89                4
# 8770  12/31/2012 10:00    -7.4              -8.9         89                4
# 8772  12/31/2012 12:00    -5.8              -7.5         88                4
# 8773  12/31/2012 13:00    -4.6              -6.6         86                4
#
#       Visibility_km  Press_kPa       Weather
# ...

# %% [markdown]
# ## Q 4. Find all the NULL values in the data ?

# %%
df.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
df.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
## not null
df.notnull().sum()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %% [markdown]
# ## Q 5. Rename the column name weather as weather condition.

# %%
df.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
df.rename(columns={'Weather':'Weater Condition'})  ## inplace=True for permanent
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %% [markdown]
# # Q 6.what is the mean visibility ?

# %%
df.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  wind_speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
df.rename(columns={'Wind Speed_km/h':'wind_speed_km/h'},inplace=True) # changing the column name because of the difficulty

# %%
df.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  wind_speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
df['wind_speed_km/h'].mean()
# Out:
# 14.94546903460838

# %% [markdown]
# # Q 7. What is the standard Deviation of any specific column?

# %%
df["wind_speed_km/h"].std()
# Out:
# 8.688696079468906

# %% [markdown]
# # Q 8.What is the variance ?

# %%
df['wind_speed_km/h'].var()
# Out:
# 75.49343956137835

# %% [markdown]
# # Q 9. Find all the instances when'SNOW" was recorded?

# %%
df.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  wind_speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
df['Weather'].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
# filtering
df[df["Weather"]=='Snow']
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  wind_speed_km/h  \
# 55       1/3/2012 7:00   -14.0             -19.5         63               19
# 84      1/4/2012 12:00   -13.7             -21.7         51               11
# 86      1/4/2012 14:00   -11.3             -19.0         53                7
# 87      1/4/2012 15:00   -10.2             -16.3         61               11
# 88      1/4/2012 16:00    -9.4             -15.5         61               13
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
# str.contains
df[df['Weather'].str.contains('Snow')].head(6)
# Out:
#          Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  wind_speed_km/h  \
# 41  1/2/2012 17:00    -2.1              -9.5         57               22
# 44  1/2/2012 20:00    -5.6             -13.4         54               24
# 45  1/2/2012 21:00    -5.8             -12.8         58               26
# 47  1/2/2012 23:00    -7.4             -14.1         59               17
# 48   1/3/2012 0:00    -9.0             -16.0         57               28
# 50   1/3/2012 2:00   -10.5             -15.8         65               22
#
#     Visibility_km  Press_kPa       Weather
# 41           25.0      99.66  Snow Showers
# 44           25.0     100.07  Snow Showers
# 45           25.0     100.15  Snow Showers
# 47           19.3     100.27  Snow Showers
# 48           25.0     100.35  Snow Showers
# 50           12.9     100.53  Snow Showers

# %% [markdown]
# # Q 10. Find out all the instances when wind speed > 24 and visibility is 25 ?

# %%
df.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  wind_speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
df[(df['wind_speed_km/h'] > 24) & (df['Visibility_km'] == 25) & (df['Weather']=='Cloudy')].head(5)
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  wind_speed_km/h  \
# 23   1/1/2012 23:00     5.3               2.0         79               30
# 25    1/2/2012 1:00     4.6               0.0         72               39
# 168   1/8/2012 0:00     0.6              -3.2         76               32
# 216  1/10/2012 0:00     2.5              -5.2         57               30
# 220  1/10/2012 4:00     1.2              -1.7         81               26
#
#      Visibility_km  Press_kPa Weather
# 23            25.0      99.31  Cloudy
# 25            25.0      99.26  Cloudy
# 168           25.0     100.72  Cloudy
# 216           25.0     100.38  Cloudy
# 220           25.0     100.07  Cloudy

# %% [markdown]
# # Q 11. What is the mean value of each column against each 'Weather condition'?

# %%
df.groupby('Weather').mean().head(5)
# Out:
#                            Temp_C  Dew Point Temp_C  Rel Hum_%  \
# Weather
# Clear                    6.825716          0.089367  64.497738
# Cloudy                   7.970544          2.375810  69.592593
# Drizzle                  7.353659          5.504878  88.243902
# Drizzle,Fog              8.067500          7.033750  93.275000
# Drizzle,Ice Pellets,Fog  0.400000         -0.700000  92.000000
#
#                          wind_speed_km/h  Visibility_km   Press_kPa
# Weather
# Clear                          10.557315      30.153243  101.587443
# Cloudy                         16.127315      26.625752  100.911441
# Drizzle                        16.097561      17.931707  100.435366
# Drizzle,Fog                    11.862500       5.257500  100.786625
# Drizzle,Ice Pellets,Fog        20.000000       4.000000  100.790000

# %% [markdown]
# # Q 12. what is the max and min value of each column against each weather conditin ?

# %%
df.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  wind_speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
df.groupby('Weather').min().head(5)
# Out:
#                                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# Weather
# Clear                     1/11/2012 1:00   -23.3             -28.5         20
# Cloudy                    1/1/2012 17:00   -21.4             -26.8         18
# Drizzle                  1/23/2012 21:00     1.1              -0.2         74
# Drizzle,Fog              1/23/2012 20:00     0.0              -1.6         85
# Drizzle,Ice Pellets,Fog  12/17/2012 9:00     0.4              -0.7         92
#
#                          wind_speed_km/h  Visibility_km  Press_kPa
# Weather
# Clear                                  0           11.3      99.52
# Cloudy                                 0           11.3      98.39
# Drizzle                                0            6.4      97.84
# Drizzle,Fog                            0            1.0      98.65
# Drizzle,Ice Pellets,Fog               20            4.0     100.79

# %%
df.groupby('Weather').max().head(5)
# Out:
#                                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# Weather
# Clear                      9/9/2012 5:00    32.8              20.4         99
# Cloudy                    9/9/2012 23:00    30.5              22.6         99
# Drizzle                   9/30/2012 3:00    18.8              17.7         96
# Drizzle,Fog               9/30/2012 2:00    19.9              19.1        100
# Drizzle,Ice Pellets,Fog  12/17/2012 9:00     0.4              -0.7         92
#
#                          wind_speed_km/h  Visibility_km  Press_kPa
# Weather
# Clear                                 33           48.3     103.63
# Cloudy                                54           48.3     103.65
# Drizzle                               30           25.0     101.56
# Drizzle,Fog                           28            9.7     102.07
# Drizzle,Ice Pellets,Fog               20            4.0     100.79

# %% [markdown]
# # Q 13. show all the records where weather condition is Fog ?

# %%
df.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  wind_speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
df[df['Weather']=='Fog']
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  wind_speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# 5        1/1/2012 5:00    -1.4              -3.3         87                9
# 6        1/1/2012 6:00    -1.5              -3.1         89                7
# ...                ...     ...               ...        ...              ...
# 8716   12/29/2012 4:00   -16.0             -17.2         90                6
# 8717   12/29/2012 5:00   -14.8             -15.9         91                4
# 8718   12/29/2012 6:00   -13.8             -15.3         88                4
# 8719   12/29/2012 7:00   -14.8             -16.4         88                7
# 8722  12/29/2012 10:00   -12.0             -13.3         90                7
#
#       Visibility_km  Press_kPa Weather
# ...

# %% [markdown]
# # Q 14. Find all the instances where weather is 'clear' or visibility is above 40 ?

# %%
df.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  wind_speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
df[(df['Weather'] == 'Clear') | (df['Visibility_km'] > 40)].head(5)
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  wind_speed_km/h  \
# 67   1/3/2012 19:00   -16.9             -24.8         50               24
# 106  1/5/2012 10:00    -6.0             -10.0         73               17
# 107  1/5/2012 11:00    -5.6             -10.2         70               22
# 108  1/5/2012 12:00    -4.7              -9.6         69               20
# 109  1/5/2012 13:00    -4.4              -9.7         66               26
#
#      Visibility_km  Press_kPa       Weather
# 67            25.0     101.74         Clear
# 106           48.3     100.45  Mainly Clear
# 107           48.3     100.41  Mainly Clear
# 108           48.3     100.38  Mainly Clear
# 109           48.3     100.40  Mainly Clear

# %% [markdown]
# # Q 15. Find all the instances when
# ### A. Weather is 'clear' and relative humidity is greater than 40
# ### or
# ### B. Visibility is greater than 40
